# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
img_path = 'blended_img.jpg'

# %%
img = cv2.imread(img_path)
img
# Out:
# array([[[231, 235, 229],
#         [231, 235, 229],
#         [231, 236, 227],
#         ...,
#         [148, 131,  98],
#         [202, 185, 152],
#         [171, 154, 121]],
#
#        [[232, 236, 225],
#         [233, 237, 226],
#         [236, 240, 229],
#         ...,
#         [127, 110,  77],
#         [169, 152, 119],
#         [145, 128,  95]],
#
#        [[239, 240, 220],
#         [238, 238, 220],
#         [240, 240, 226],
#         ...,
#         [179, 160, 127],
#         [174, 155, 122],
#         [145, 126,  93]],
#
#        ...,
#
#        [[244, 246, 226],
#         [244, 246, 226],
#         [244, 246, 226],
#         ...,
#         [229, 229, 223],
#         [232, 232, 226],
#         [220, 220, 214]],
#
#        [[244, 246, 226],
#         [244, 246, 226],
#         [244, 246, 226],
#         ...,
#         [241, 241, 235],
#         [216, 216, 210],
#         [217, 217, 211]],
#
#        [[244, 246, 226],
#         [244, 246, 226],
#         [244, 246, 226],
#         ...,
#         [245, 245, 239],
#         [248, 248, 242],
#         [233, 233, 227]]], dtype=uint8)

# %%
h,w,c =img.shape
print(f'height of the image:{h}','\n')
print(f'width of the image:{w}','\n')
print(f'color channels of the image:{c}')
# Out:
# height of the image:600
#
# width of the image:800
#
# color channels of the image:3

# %%
img.shape
# Out:
# (600, 800, 3)

# %%
plt.imshow(img)
plt.show()

# %%
recolor = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(recolor)
plt.show()

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()

# %%
cv2.imwrite('gray_img.jpg',gray)
# Out:
# True
